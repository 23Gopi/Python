# %%
print()

# %%
print("Hellow World...!")
# Out:
# Hellow World...!

# %%
print("0934&#&$asdf")
# Out:
# 0934&#&$asdf

# %%
Print('Welcome')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0c415cab36e3> in <module>
# ----> 1 Print('Welcome')
#
# NameError: name 'Print' is not defined

# %%
def ageCategory():
        if(age<18):
            print("Childrens")
            cate="Childrens"
        elif(age<35):
            print("Adults")
            cate="Adults"
        elif(age<59):
            print("Citizens")
            cate="Citizens"
        else:
            print("Senior Citizens")
            cate="Senior Citizens"
        return cate

# %%
age=int(input("Enter the age:"))
ageCate=ageCategory()
# Out:
# Enter the age:20
# Adults

# %%
ageCate
# Out:
# 'Adults'

# %%
def oddOrEven():
    num=int(input("Enter the Number"))
    if(num %2 == 1):
        message = "Odd Number"
    else:
        message = "Even Number"
    return message;

# %%
oddOrEven()
# Out:
# Enter the Number1435
# 'Odd Number'

# %%
def BMI():
    index=int(input("Enter the BMI Index:"))
    if(index<19):
        print("Under Weight")
        bodyState="Under Weight"
    elif(index<25):
        print("Normal Weight")
        bodyState="Normal Weight"
    elif(index<30):
        print("Over Weight")
        bodyState="Over Weight"
    elif(index<35):
        print("Obisity Class 1")
        bodyState="Obisity Class 1"
    elif(index<40):
        print("Obisity Class 2") 
        bodyState="Obisity Class 2"
    else:
        print("Obisity Class 3")
        bodyState="Obisity Class 3"
    return bodyState

# %%
BMI()
# Out:
# Enter the BMI Index:20
# Normal Weight
# 'Normal Weight'

# %%
from assignmentFunctions import SubfieldsInAI, OddEven, ElegiblityForMarriage, FindPercent, Triangle

# %%
SubfieldsInAI.subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
OddEven.oddOrEven()
# Out:
# Enter a Number7564
# 7564 is Even Number

# %%
ElegiblityForMarriage.elegible("Male", 21)
# Out:
# Your Gender:  Male
# Your Age:  21
# Eligible for marriage

# %%
ElegiblityForMarriage.elegible("Male", 20)
# Out:
# Your Gender:  Male
# Your Age:  20
# Not Eligible for marriage

# %%
ElegiblityForMarriage.elegible("FeMale", 21)
# Out:
# Your Gender:  FeMale
# Your Age:  21
# Eligible for marriage

# %%
ElegiblityForMarriage.elegible("FeMale", 16)
# Out:
# Your Gender:  FeMale
# Your Age:  16
# Not Eligible for marriage

# %%
marks = [98, 87, 95, 95, 93]
FindPercent.percentage(marks)
# Out:
# FindPercent.percentage()
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total  : 468
# Percentage : 93.6

# %%
Triangle.areaOfTriangle(32, 34)
Triangle.perimeterOfTriangle(2, 4, 4)
# Out:
# Height: 32
# Breadth: 34
# Area formula: (Height*Breadth)/2
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10

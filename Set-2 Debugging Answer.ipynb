# %%
#1.Find the error in the following Python code:
#import math
#print(Math.sqrt(16))
#Answer: The error in the code is that 'Math' should be lowercase 'math'. The corrected
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
#def my_function():
#    x += 5
#    print(x)

#x = 10
#my_function()

#Answer: The error in the code is that the variable 'x' is being used before it is assigned
def my_function():
    global x
    x += 5
    print(x)

x = 10
my_function()
# Out:
# 15

# %%
#3.x = 5
#if x = 10:
#    print("x is 10")

#Answer: The error in the code is the use of '=' instead of '==' in the if statement.
x = 10
if x == 10:
    print("x is 10")
# Out:
# x is 10

# %%
#4.
#numbers = [5, 3, 8, 2]
#print(numbers.sort())

#Answer: The error in the code is that the sort() method sorts the list in place and returns
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
#def square(n):
#    n * n

#print(square(4))

#Answer: The error in the code is that the function 'square' does not return any value.
def square(n):
    return n * n

print(square(4))
# Out:
# 16

# %%
#6.
#my_tuple = (1, 2, 3)
#my_tuple[1] = 5


#Answer: The error in the code is that tuples are immutable, and you cannot change their elements.
my_tuple = (1, 2, 3)
# Tuples are immutable, so create a new tuple
my_tuple = (1, 5, 3)
print(my_tuple)
# Out:
# (1, 5, 3)

# %%
#7.name = "Alice"
#age = 25
#print("My name is %s and I am %d years old" % (name))

#Answer: The error in the code is that the format string expects two values (name and age), but only one value (name) is provided in the tuple.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name, age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
#a = [1, 2, 3]
#b = [1, 2, 3]
#if a is b:
#    print("Lists are equal")

#Answer: The error in the code is that 'is' checks for identity, not equality. Use '==' to compare values.
a = [1, 2, 3]
b = [1, 2, 3]

if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.
#for i in range(5, 1):
#    print(i)
#Answer: The error in the code is that the range function should have the start value less than the end value. It should be range(1, 5).
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4
